# %% [markdown]
# ## A simple calculator using functions
#
# 1) Read code and discuss - ask questions!
#
# 2) Comment code
#
# 3) Extend the calculator with 5 more functions

# %%
def mainMenu():
    validChoices = ["A", "S","M","D",'P','Y','R']    #valid input opptions
    valid = False
    while not valid:
        print("A) Add numbers")
        print("S) Subtract numbers")
        print('M) Multiply numbers')
        print('D) Divide numbers')
        print('P) Numbers to the power of')
        print('Y) Presto exit')
        print('R) Ruting numbers')
        choice = input("choose your option\n>").upper()
        if choice not in validChoices:
            print("sorry that is not a valid menu choice ")
        else:
            valid= True        #decides that input was valid
            
    return choice
    
    

            
            
def enterNumber(a):                #alowes numbers to be inputed
    valid = False
    while not valid:
        try:
            if a==1:
                a='first'
            else:
                a='second'
            x=float(input('enter the '+a+' number\n>'))
            valid=True            dicides that a number was inputed
        except ValueError:
            print("That was not a valid number.. please try again")    #error mesage
    
    return x

def add(x,y):
    answer=x+y        #adds the 2 numbers
    if (answer== round(answer)):
        answer=int(answer)
    return answer

def subtract(x,y):
    answer=x-y        #subtracts the 2 numbers
    if (answer== round(answer)):
        answer=int(answer)
    return answer

def multiply(x,y):
    answer=x*y        #multyplies numbers
    if (answer== round(answer)):
        answer=int(answer)
    return answer

def divide(x,y):
    try:
        answer=x/y    #divides numbers
        if (answer== round(answer)):
            answer=int(answer)
        return answer
    except:
        print('Mathematical error')            #in case y=0 then that will resolt in a matematical error

def powers(x,y):
    answer=x**y        #number to the power of other number
    if (answer== round(answer)):
        answer=int(answer)
    return answer

def ruting(x,y):
    try:
        y=1/y        #used to trans form in to power format
        answer=powers(x,y)
        if (answer== round(answer)):
            answer=int(answer)
        return answer
    except:
        print('Mathematical error')            #in case y=0 then that will resolt in a matematical error


#main program starts here
print("welcome to my calculator")

while True:
    
    userChoice = mainMenu()
    if userChoice == "A":                  #adds 2 numbers
        print('eg: no.1=1,no.2=2\t1+2')
        answer = add(enterNumber(1), enterNumber(2))
    elif userChoice == "S":                #subtract the numbers
        print('eg: no.1=1,no.2=2\t1-2')
        answer = subtract(enterNumber(1), enterNumber(2))
    elif userChoice == "M":                #multyply numbers
        print('eg: no.1=1,no.2=2\t1*2')
        answer = multiply(enterNumber(1), enterNumber(2))
    elif userChoice == "D":                #devides numbers
        print('eg: no.1=1,no.2=2\t1/2')
        answer = divide(enterNumber(1), enterNumber(2))
    elif userChoice == "P":                #numbers to the power of other numbers
        print('eg: no.1=1,no.2=2\t1*1')
        answer = powers(enterNumber(1), enterNumber(2))
    elif userChoice == "R":                #numbers ruted tho the other number
        print('eg: no.1=1,no.2=2\t1 squerruted')
        answer = ruting(enterNumber(1), enterNumber(2))
    elif userChoice == "Y":                #ends the proces
        break
    else:
        print("error - we should never get here")
    
    print('\n'*3+'The answer from your calcaulation is = '+str(answer))
# Out:
# welcome to my calculator
# A) Add numbers
# S) Subtract numbers
# M) Multiply numbers
# D) Divide numbers
# P) Numbers to the power of
# Y) Presto exit
# R) Ruting numbers
# choose your option
# >r
# eg: no.1=1,no.2=2	1 squerruted
# enter the first number
# >3
# enter the second number
# >1
#
#
#
# The answer from your calcaulation is = 3
# A) Add numbers
# S) Subtract numbers
# M) Multiply numbers
# D) Divide numbers
# P) Numbers to the power of
# Y) Presto exit
# R) Ruting numbers
